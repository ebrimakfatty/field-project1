# %%
#sessions_per_counselor.csv

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

df = pd.read_csv("sessions_per_counselor.csv")
print(df.head())
plt.figure()
plt.bar(df["name"], df["total_sessions"])
plt.xticks(rotation=45)
plt.xlabel("Counselor")
plt.ylabel("Total Sessions")
plt.title("Sessions Handled per Counselor")
plt.show()
# Out:
#      <input type="file" id="files-623b5676-d2a7-4e4d-a4bc-99ae6aa8401c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-623b5676-d2a7-4e4d-a4bc-99ae6aa8401c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#beneficiarys_gender_new.csv

import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files
uploaded = files.upload()

df = pd.read_csv("beneficiarys_gender_new.csv")

plt.pie(df['total'], labels=df['gender'], autopct='%1.1f%%')
plt.title("Beneficiaries by Gender")
plt.show()
# Out:
#      <input type="file" id="files-6e2401c7-f05d-41b5-9c5f-e170e7260aff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e2401c7-f05d-41b5-9c5f-e170e7260aff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#monthlys_sessions_new.csv

import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files
uploaded = files.upload()

df = pd.read_csv("monthlys_sessions_new.csv")

plt.plot(df['month'], df['total_sessions'], marker='o')
plt.title("Monthly Counseling Sessions")
plt.xlabel("Month")
plt.ylabel("Total Sessions")
plt.show()
# Out:
#      <input type="file" id="files-dd7121c9-b8ea-400e-98a2-95ba0c414e33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd7121c9-b8ea-400e-98a2-95ba0c414e33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#beneficiaries_per_programs.csv

import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files
uploaded = files.upload()

df = pd.read_csv("beneficiaries_per_programs.csv")

plt.bar(df['program_name'], df['total_beneficiaries'])
plt.xticks(rotation=45)
plt.title("Beneficiaries per Program")
plt.xlabel("Program")
plt.ylabel("Total Beneficiaries")
plt.show()
# Out:
#      <input type="file" id="files-1e589580-a920-4288-b1d2-0526416655ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e589580-a920-4288-b1d2-0526416655ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
